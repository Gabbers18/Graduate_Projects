# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabbers18/Python_Projects/blob/main/Final_Project/BriefProjectDescriptionAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Final Project - Exploring Young People Survey Data Spending Habits**
# **By: Gabrielle Young**
#
# The dataset I will be exploring looks into young people's spending habits. The dataset can be accessed [here](https://github.com/harsh543/Young-People-Survey-Dataset_Spending-Habits/blob/master/data/responses.csv).
#
#  This dataset contains massive survey data from young people, ranging from music preferences to spending preferences. This dataset has 1011 individuals represented by each row and 151 variables.
#
#
#  **Research Questions**
#  1. Can we predict poor spending habits from a person's demographics? For example, if a person has more education, will they be less likely to spend more? Another example would be whether age effects spending habits. Does gender effect spending habits? To answer these questions, I would have to calcuate the proportion of spending to income.
#  2. How do individuals compare to one another across similar circumstances? For example, do people with similar music preferences have similar spending habits? With this, I wanted to create a machnine learning model using many variables as inputs and most likely a combined variable averaging spending habits across individuals.

# %% [markdown]
# **Analysis Plan**
#
# I want to first run some exploratory analyses:
# - Distributions of the sample's demographics (gender, age, education, etc.).
# - Visualize ospending habits (1 represents did not spend a lot on 5 spending very much)
# - Visualize types of music in comparison to spending habits
#
#
# Next, I want to create a few models to represent the data:
# - logistic regression model
# - random forest model
# - decision tree model
#
# This is something I have done in R, but I want to learn to do this in python.
#
# After, I will compare the accuracy across models using their metrics and select the best model. I will then run these models on the test data and see how well they perform. I want to create a series of visualizations to illustrate performance of the models, too.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
spending= pd.read_csv('responses (2).csv')

# %%
spending.head(20)
# Out:
#     Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0     5.0                       3.0    2.0   1.0      2.0              2.0
# 1     4.0                       4.0    2.0   1.0      1.0              1.0
# 2     5.0                       5.0    2.0   2.0      3.0              4.0
# 3     5.0                       3.0    2.0   1.0      1.0              1.0
# 4     5.0                       3.0    4.0   3.0      2.0              4.0
# 5     5.0                       3.0    2.0   3.0      2.0              3.0
# 6     5.0                       5.0    5.0   3.0      1.0              2.0
# 7     5.0                       3.0    3.0   2.0      1.0              2.0
# 8     5.0                       3.0    3.0   1.0      1.0              2.0
# 9     5.0                       3.0    2.0   5.0      2.0              2.0
# 10    5.0                       3.0    3.0   2.0      1.0              2.0
# 11    5.0                       3.0    1.0   1.0      1.0              4.0
# 12    5.0                       3.0    1.0   2.0      1.0              4.0
# 13    5.0                       3.0    5.0   3.0      2.0              1.0
# 14    5.0                       3.0    2.0   1.0      1.0              2.0
# 15    1.0                       3.0    2.0   2.0      3.0              4.0
# 16    5.0                       3.0    3.0   1.0      1.0              1.0
# 17    5.0                       3.0    3.0   3.0      3.0              2.0
# 18    5.0                       3.0    5.0   4.0      3.0              4.0
# 19    5.0                       4.0    3.0   3.0      2.0              4.0
#
#     Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0       1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1       2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2       5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3       1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4       3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# 5       3.0  2.0   5.0                5.0  ...  20.0   186.0    77.0
# 6       2.0  5.0   3.0                1.0  ...  20.0   177.0    50.0
# 7       2.0  4.0   5.0                1.0  ...  19.0   184.0    90.0
# 8       4.0  3.0   5.0                5.0  ...  18.0   166.0    55.0
# 9       5.0  3.0   5.0                2.0  ...  19.0   174.0    60.0
# 10      3.0  4.0   3.0                2.0  ...  19.0   175.0    60.0
# 11      1.0  2.0   5.0                1.0  ...  17.0   176.0    60.0
# 12      3.0  3.0   5.0                4.0  ...  24.0   168.0    55.0
# 13      5.0  5.0   2.0                1.0  ...  19.0   165.0    55.0
# 14      3.0  4.0   5.0                2.0  ...  22.0   175.0    57.0
# 15      3.0  3.0   5.0                5.0  ...  18.0   177.0    77.0
# 16      2.0  4.0   4.0                1.0  ...  19.0   175.0    65.0
# 17      2.0  4.0   4.0                2.0  ...  20.0   168.0    65.0
# 18      5.0  5.0   4.0                4.0  ...  18.0   181.0    78.0
# 19      2.0  2.0   4.0                5.0  ...  18.0   188.0    90.0
#
#     Number of siblings  Gender  Left - right handed                Education  \
# 0                  1.0  female         right handed  college/bachelor degree
# 1                  2.0  female         right handed  college/bachelor degree
# 2                  2.0  female         right handed         secondary school
# 3                  1.0  female         right handed  college/bachelor degree
# 4                  1.0  female         right handed         secondary school
# 5                  1.0    male         right handed         secondary school
# 6                  1.0  female         right handed         secondary school
# 7                  1.0    male         right handed  college/bachelor degree
# 8                  1.0  female         right handed         secondary school
# 9                  3.0  female         right handed         secondary school
# 10                 2.0  female          left handed         secondary school
# 11                 1.0  female         right handed           primary school
# 12                10.0  female         right handed  college/bachelor degree
# 13                 1.0  female         right handed         secondary school
# 14                 1.0  female         right handed  college/bachelor degree
# 15                 0.0    male         right handed         secondary school
# 16                 2.0  female         right handed  college/bachelor degree
# 17                 1.0  female         right handed         secondary school
# 18                 2.0    male         right handed         secondary school
# 19                 1.0    male          left handed         secondary school
#
#     Only child  Village - town  House - block of flats
# 0           no         village          block of flats
# 1           no            city          block of flats
# 2           no            city          block of flats
# 3          yes            city          house/bungalow
# 4           no         village          house/bungalow
# 5           no            city          block of flats
# 6           no         village          house/bungalow
# 7           no            city          house/bungalow
# 8           no            city          house/bungalow
# 9           no            city          block of flats
# 10          no            city          block of flats
# 11          no            city          block of flats
# 12          no            city          block of flats
# 13          no            city          block of flats
# 14          no            city          block of flats
# 15         yes            city          block of flats
# 16          no            city          block of flats
# 17          no         village          house/bungalow
# 18          no            city          house/bungalow
# 19          no            city          house/bungalow
#
# [20 rows x 150 columns]

# %%
selected_columns = spending[['Music', 'Spending on healthy eating', 'Gender', 'Age','Spending on looks', 'Spending on gadgets', 'Education', 'Entertainment spending']]
print(selected_columns)

selected_columns.head(20)
# Out:
#       Music  Spending on healthy eating  Gender   Age  Spending on looks  \
# 0       5.0                         3.0  female  20.0                3.0
# 1       4.0                         2.0  female  19.0                2.0
# 2       5.0                         2.0  female  20.0                3.0
# 3       5.0                         1.0  female  22.0                4.0
# 4       5.0                         4.0  female  20.0                3.0
# ...     ...                         ...     ...   ...                ...
# 1005    5.0                         4.0  female  20.0                4.0
# 1006    4.0                         3.0    male  27.0                1.0
# 1007    4.0                         5.0  female  18.0                2.0
# 1008    5.0                         3.0  female  25.0                3.0
# 1009    5.0                         5.0    male  21.0                1.0
#
#       Spending on gadgets                Education  Entertainment spending
# 0                       1  college/bachelor degree                     3.0
# 1                       5  college/bachelor degree                     4.0
# 2                       4         secondary school                     4.0
# 3                       4  college/bachelor degree                     3.0
# 4                       2         secondary school                     3.0
# ...                   ...                      ...                     ...
# 1005                    3         secondary school                     3.0
# 1006                    5           masters degree                     1.0
# 1007                    2         secondary school                     2.0
# 1008                    3  college/bachelor degree                     5.0
# 1009                    1         secondary school                     3.0
#
# [1010 rows x 8 columns]
#     Music  Spending on healthy eating  Gender   Age  Spending on looks  \
# 0     5.0                         3.0  female  20.0                3.0
# 1     4.0                         2.0  female  19.0                2.0
# 2     5.0                         2.0  female  20.0                3.0
# 3     5.0                         1.0  female  22.0                4.0
# 4     5.0                         4.0  female  20.0                3.0
# 5     5.0                         4.0    male  20.0                1.0
# 6     5.0                         5.0  female  20.0                4.0
# 7     5.0                         2.0    male  19.0                4.0
# 8     5.0                         4.0  female  18.0                1.0
# 9     5.0                         4.0  female  19.0                3.0
# 10    5.0                         2.0  female  19.0                4.0
# 11    5.0                         2.0  female  17.0                1.0
# 12    5.0                         3.0  female  24.0                3.0
# 13    5.0                         3.0  female  19.0                4.0
# 14    5.0                         4.0  female  22.0                5.0
# 15    1.0                         5.0    male  18.0                3.0
# 16    5.0                         3.0  female  19.0                3.0
# 17    5.0                         5.0  female  20.0                2.0
# 18    5.0                         4.0    male  18.0                4.0
# 19    5.0                         3.0    male  18.0                3.0
#
#     Spending on gadgets                Education  Entertainment spending
# 0                     1  college/bachelor degree                     3.0
# 1                     5  college/bachelor degree                     4.0
# 2                     4         secondary school                     4.0
# 3                     4  college/bachelor degree                     3.0
# 4                     2         secondary school                     3.0
# 5                     4         secondary school                     3.0
# 6                     1         secondary school                     3.0
# 7                     3  college/bachelor degree                     4.0
# 8                     3         secondary school                     2.0
# 9                     2         secondary school                     2.0
# 10                    2         secondary school                     3.0
# 11                    1           primary school                     3.0
# 12                    2  college/bachelor degree                     2.0
# 13                    3         secondary school                     3.0
# 14                    1  college/bachelor degree                     5.0
# 15                    5         secondary school                     3.0
# 16                    3  college/bachelor degree                     3.0
# 17                    2         secondary school                     NaN
# 18                    5         secondary school                     4.0
# 19                    3         secondary school                     4.0

# %% [markdown]
# ##**Exploratory Analysis/Visualizations**
#
# **Descriptive Statistics - Demographics**

# %%
spending[['Gender', 'Age', 'Education']].describe(include='all')
# Out:
#         Gender          Age         Education
# count     1004  1003.000000              1009
# unique       2          NaN                 6
# top     female          NaN  secondary school
# freq       593          NaN               621
# mean       NaN    20.433699               NaN
# std        NaN     2.828840               NaN
# min        NaN    15.000000               NaN
# 25%        NaN    19.000000               NaN
# 50%        NaN    20.000000               NaN
# 75%        NaN    22.000000               NaN
# max        NaN    30.000000               NaN
